# %%
using Plots
using PlotThemes
theme(:dark)
# Out:
# (process:16164): GLib-GIO-WARNING **: 18:32:33.861: Unexpectedly, UWP app `Clipchamp.Clipchamp_2.2.8.0_neutral__yxz26nhyzhsrt' (AUMId `Clipchamp.Clipchamp_yxz26nhyzhsrt!App') supports 46 extensions but has no verbs

# %%
x = LinRange(-2,3,40)
y = 2 .* x.^2 .+ 4
plot(x, y, label="hw", xlabel="time", shape=:circle)
plot!(x, x -> x^3 + x^2 + x, color="green", ylabel="value")  # 原图追加

# %%
x = LinRange(0, 30, 1000)
y = cos.(x) .* x
z = sin.(x) .* x
plot(x, y, z)

# %%
savefig("../img/22.pdf")

# %%
m=1:5
# Out:
# 1:5
