# %%
using Plots

# %%
v = LinRange(0,30,50)
B = 18.3
y = B*v.^0.55
plot(v, y, label="hw", xlabel="time", shape=:circle)
plot!(v, v -> 12.12 - 1.16v + 11.6v.^0.5, color="green", ylabel="value")  # 原图追加

# %%
x = LinRange(0, 30, 1000)
y = cos.(x) .* x
z = sin.(x) .* x
plot(x, y, z)

# %%
savefig("../img/22.pdf")
# Out:
# "d:\\OneDrive\\ProgramCode\\GitHub\\JuliaLearn\\img\\22.pdf"

# %%
m=1:5
# Out:
# 1:5
